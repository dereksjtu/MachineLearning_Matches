# %%
# -*- coding:urf-8 -*-
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table like and matrices
import pandas as pd
import numpy as np

# Modeling Helper
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import missingno as msno

# Configure visualization
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 10,8

train_path = '../input/train.csv'
test_path = '../input/test.csv'
hol_path = '../input/holiday.csv'
train_date_path = '../input/train_date.csv'
cache_path = '../input/cache/'
output_path = '../output/'
train_new_path = 'train_new_total.csv'
train_new = pd.read_csv(train_new_path)
test = pd.read_csv(test_path)

# %%
fig,axs = plt.subplots(nrows=2,ncols=1)
train_new['saleCount'].hist(bins=100,ax=axs[0])
train_new['saleCount'] = np.log1p(train_new['saleCount'])
train_new['saleCount'].hist(bins=100,ax=axs[1])
plt.show()
